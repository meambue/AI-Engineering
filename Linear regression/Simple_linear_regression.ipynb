# %% [markdown]
#  # Objective
#  - Use scikit-learn to implement simple regression
#  - Create, train and test linear refression model on real data

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
import io
from pathlib import Path

# Read the local CSV file into a string variable named `url`
url = Path('c:/Users/medea/OneDrive/Desktop/AI Engineering/AI-Engineering/auto-mpg[1].csv').read_text(encoding='utf-8')
# Parse the CSV string with pandas using StringIO
df = pd.read_csv(io.StringIO(url))
# Quick diagnostics to confirm the file was parsed correctly
print('Columns:', df.columns.tolist())
print('








print(df['model year'].value_counts().sort_index())print('
Model year value counts (sorted):')print('Model year unique (sorted):', sorted(df['model year'].dropna().unique()))print('
Model year sample:', df['model year'].head().tolist())# Inspect the 'model year' column specificallydf.head()print('
First 5 rows:')print(df.dtypes)Dtypes:')
# Out:
# <bound method NDFrame.head of       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...
